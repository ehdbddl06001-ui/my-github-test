# %% [markdown]
# <a href="https://colab.research.google.com/github/ehdbddl06001-ui/my-github-test/blob/claude%2Fexp-2026-002-q4p-best-epoch-zero-diagnostic/exp-2026-002-q4p-best-epoch-zero-diagnostic/notebooks/quest48_q4p_best_epoch_zero_diagnostic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EXP-2026-002 / Q4-P — `best_epoch = 0` 원인 분리 진단
#
# **상태: EXPLORATORY DIAGNOSTIC / FULL RESULT NOT RUN.**
#
# Q4-O(NO-GO)의 Arm C가 25개 (seed × fold) 전부에서 첫 학습 epoch 완료 후 체크포인트
# (`best_epoch = 0`)를 선택한 원인을 분리한다: 즉시 유해(H1) / 첫 epoch 후 과적합(H2) /
# LR·alpha overshoot(H3) / selector 불일치(H4).
#
# - spec: `experiments/specs/EXP-2026-002-q4p-best-epoch-zero-diagnostic.md`
# - 고정: Q4-O의 데이터·fold map·seeds·모델·offset. 바뀌는 것은 **학습 trajectory와 checkpoint 정의**뿐.
# - 학습 전 상태를 `epoch = -1` 체크포인트로 **직접 평가**한다 (Q4-O가 하지 못한 비교).
# - 세 schedule(S0/S1/S2) × 세 selector(SEL0/SEL1/SEL2), 고정 24 epoch, patience 없음.
# - Q4-O의 측정 artifact는 읽지도, 쓰지도 않는다 — 완전히 별도 run 디렉터리를 만든다.

# %% [markdown]
# ## 1. Drive mount + 최신 코드

# %%
import os, sys, subprocess, time, importlib

REPO_URL     = "https://github.com/ehdbddl06001-ui/my-github-test.git"
REPO_BRANCH  = "claude/exp-2026-002-q4p-best-epoch-zero-diagnostic"
REPO_DIR     = "/content/my-github-test"
NEED_Q4O     = 4          # Q4-O module version this design depends on
NEED_Q4P     = 1

try:
    from google.colab import drive
    drive.mount("/content/drive", force_remount=False)
    DRIVE_ROOT = "/content/drive/MyDrive"
except Exception as exc:
    print("not Colab:", exc)
    DRIVE_ROOT = os.environ.get("MEDKOS_DRIVE_ROOT", "/content")

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--branch", REPO_BRANCH, REPO_URL, REPO_DIR],
                   check=True)
else:
    subprocess.run(["git", "-C", REPO_DIR, "fetch", "origin", REPO_BRANCH], check=True)
    subprocess.run(["git", "-C", REPO_DIR, "checkout", REPO_BRANCH], check=True)
    subprocess.run(["git", "-C", REPO_DIR, "reset", "--hard",
                    f"origin/{REPO_BRANCH}"], check=True)

MOD_DIR = os.path.join(REPO_DIR, "mit-bih")
if MOD_DIR not in sys.path:
    sys.path.insert(0, MOD_DIR)

# Purge stale imports — a kernel that holds an old module silently ignores git pull.
for _name in [m for m in sys.modules
              if m.startswith(("q4o_leakage_free_residual",
                               "q4p_best_epoch_zero_diagnostic"))]:
    del sys.modules[_name]
importlib.invalidate_caches()

import q4o_leakage_free_residual as Q4O
import q4p_best_epoch_zero_diagnostic as QP

assert Q4O.MODULE_VERSION >= NEED_Q4O, (
    f"stale Q4-O module {Q4O.MODULE_VERSION} < {NEED_Q4O} - restart the runtime")
check = QP.self_check(min_version=NEED_Q4P)
print("q4p module :", check["module_file"])
print("version    :", check["module_version"], "-", check["module_build"])
print("status     :", check["status"])
print("repo commit:", Q4O.git_commit_sha(REPO_DIR))
print("packages   :", Q4O.package_versions())
print("gpu        :", Q4O.gpu_info())
# Out:
# Mounted at /content/drive
# q4p module : /content/my-github-test/mit-bih/q4p_best_epoch_zero_diagnostic.py
# version    : 1 - 2026-08-08 q4p.1 — design; no full run has been executed
# status     : EXPLORATORY DIAGNOSTIC / RESULT NOT RUN
# repo commit: a4e24f4d662b3a93727f6a3413e594b51cc6205e
# packages   : {'python': '3.12.13', 'platform': 'Linux-6.6.122+-x86_64-with-glibc2.35', 'numpy': '2.0.2', 'scipy': '1.16.3', 'sklearn': '1.6.1', 'pandas': '2.2.2', 'torch': '2.11.0+cu128', 'matplotlib': '3.10.0'}
# gpu        : {'cuda_available': True, 'device_name': 'Tesla T4', 'cuda_version': '12.8', 'device_count': 1}

# %% [markdown]
# ## 2. 테스트 먼저 (Q4-O 스위트 + Q4-P 스위트)

# %%
for test_file in ("test_q4o_leakage_free_residual.py",
                  "test_q4p_best_epoch_zero_diagnostic.py"):
    rc = subprocess.run([sys.executable, os.path.join(MOD_DIR, test_file)],
                        capture_output=True, text=True)
    print(rc.stdout[-1500:])
    if rc.returncode != 0:
        print(rc.stderr[-2500:])
        raise SystemExit(f"{test_file} failed - do not run anything further")
print("both suites passed in a subprocess; in-kernel versions re-verified below")
assert QP.MODULE_VERSION >= NEED_Q4P
QP.self_check(min_version=NEED_Q4P)
print("in-kernel q4p module verified")
# Out:
#  / 'guaranteed lower bound' claims
# ------------------------------------------------------------------------------
#   PASS  module carries no pre-training-restore claim (clean)
#   PASS  spec carries no pre-training-restore claim (clean)
#   PASS  notebook carries no pre-training-restore claim (clean)
#
# ------------------------------------------------------------------------------
# 18. fingerprint — training_history.json included iff the run wrote one
# ------------------------------------------------------------------------------
#   PASS  a run without training_history.json is fingerprinted without it
#   PASS  fingerprinting a history-less run does not create the file
#   PASS  a run that wrote training_history.json gets it fingerprinted — reporting can no longer alter it silently
#   PASS  adding the history changes nothing about the other artifacts' hashes
#
# ------------------------------------------------------------------------------
# 19. Windows CP949 console — the runner does not die on em dashes
# ------------------------------------------------------------------------------
#   PASS  a strict cp949 stream rejects an em dash (this is what is guarded)
#   PASS  after _harden_stdout() the banner prints on a cp949 console without raising
#   PASS  the output still reaches the console (characters replaced, not dropped)
#
# ==============================================================================
# passed 218 · failed 0
# ==============================================================================
#
# ry is fingerprinted without one
#   PASS  fingerprinting did not create the file
#   PASS  verify_bundle reports the missing history instead of writing one (Q4-P runs are contracted to record it)
#   PASS  and still no file was invented afterwards
#
# ------------------------------------------------------------------------------
# 12. reuse — Q4-P imports Q4-O's frozen machinery, no local copies
# ------------------------------------------------------------------------------
#   PASS  Q4-P imports the Q4-O module
#   PASS  'def build_features' is not redefined in Q4-P — the Q4-O definition is the one that runs
#   PASS  'def make_fold_map' is not redefined in Q4-P — the Q4-O definition is the one that runs
#   PASS  'def cross_fitted_offsets' is not redefined in Q4-P — the Q4-O definition is the one that runs
#   PASS  'def build_residual_net' is not redefined in Q4-P — the Q4-O definition is the one that runs
#   PASS  'def shuffle_waveforms_within_record' is not redefined in Q4-P — the Q4-O definition is the one that runs
#   PASS  'def paired_record_bootstrap' is not redefined in Q4-P — the Q4-O definition is the one that runs
#   PASS  'def achievement_at' is not redefined in Q4-P — the Q4-O definition is the one that runs
#   PASS  the model builder is literally Q4-O's object
#   PASS  S0_original reproduces Q4-O's LR exactly
#
# ==============================================================================
# passed 87 · failed 0
# ==============================================================================
#
# both suites passed in a subprocess; in-kernel versions re-verified below
# in-kernel q4p module verified

# %% [markdown]
# ## 3. 모드 선택 — 동시에 정확히 하나만

# %%
# ---------------------------------------------------------------------------
# DESIGN_ONLY           : 설계 요약만 출력. 아무것도 학습/실행하지 않는다. (기본)
# SMOKE                 : CPU synthetic smoke run — 배관 검증. 과학적 의미 없음.
# FULL_RUN              : 실제 GPU run (svdb_data5.npz). 이번 작업에서는 실행 금지.
# ANALYZE_EXISTING_RUN  : 완료된 Q4-P run 번들의 보고만 재생성.
# ---------------------------------------------------------------------------
DESIGN_ONLY          = False
SMOKE                = False
FULL_RUN             = True
ANALYZE_EXISTING_RUN = False
EXISTING_RUN_DIR     = ""     # ANALYZE_EXISTING_RUN=True 일 때만 사용

_modes = [DESIGN_ONLY, SMOKE, FULL_RUN, ANALYZE_EXISTING_RUN]
assert sum(bool(m) for m in _modes) == 1, (
    f"exactly ONE mode must be active, got {_modes}")

DATA_PATH = os.path.join(DRIVE_ROOT, "mitbih", "svdb_data5.npz")
PROJECT   = os.path.join(DRIVE_ROOT, "MedKOS", "ecg-model")
RUNS_DIR  = os.path.join(PROJECT, "runs")

MODE = ("DESIGN_ONLY" if DESIGN_ONLY else "SMOKE" if SMOKE
        else "FULL_RUN" if FULL_RUN else "ANALYZE_EXISTING_RUN")
print("MODE :", MODE)
print("schedules :", list(QP.SCHEDULES))
print("selectors :", list(QP.SELECTORS), "(primary:", QP.PRIMARY_SELECTOR + ")")
print("epochs    :", QP.N_EPOCHS, "fixed - patience never stops the optimizer")
print("checkpoint: epoch -1 (pre-training) is a first-class candidate")
# Out:
# MODE : FULL_RUN
# schedules : ['S0_original', 'S1_global_low', 'S2_alpha_low']
# selectors : ['SEL0_pooled_bce', 'SEL1_record_bce', 'SEL2_record_ksweep'] (primary: SEL1_record_bce)
# epochs    : 24 fixed - patience never stops the optimizer
# checkpoint: epoch -1 (pre-training) is a first-class candidate

# %% [markdown]
# ## 4. 설계 요약 (DESIGN_ONLY)

# %%
if DESIGN_ONLY:
    n_traj = 2 * len(QP.SCHEDULES) * len(Q4O.TRAIN_SEEDS) * Q4O.N_OUTER_FOLDS
    print("=" * 74)
    print("EXP-2026-002 / Q4-P - DESIGN SUMMARY (nothing executed)")
    print("=" * 74)
    print(f"arms          : C (real waveform) + D (within-record shuffle); A as reference")
    print(f"trajectories  : {n_traj} = 2 arms x {len(QP.SCHEDULES)} schedules x "
          f"{len(Q4O.TRAIN_SEEDS)} seeds x {Q4O.N_OUTER_FOLDS} folds")
    print(f"checkpoints   : {QP.N_EPOCHS + 1} per trajectory (epoch -1 .. {QP.N_EPOCHS - 1})")
    print(f"tie tolerance : BCE {QP.TIE_TOL_BCE} / k-sweep {QP.TIE_TOL_KSW} "
          f"(tie -> earliest checkpoint incl. -1)")
    print(f"grad logging  : first {QP.GRAD_LOG_STEPS} optimizer steps per trajectory")
    print()
    print("pre-registered decision branches:")
    for b in QP.DECISION_BRANCHES:
        print("  -", b)
    print()
    print("FULL RESULT NOT RUN - every result cell below shows NOT RUN.")
else:
    print("skipped - not in DESIGN_ONLY mode")
# Out:
# skipped - not in DESIGN_ONLY mode

# %% [markdown]
# ## 5. 실행 (SMOKE / FULL_RUN / ANALYZE_EXISTING_RUN)

# %%
result = None
OUT_DIR = None
if DESIGN_ONLY:
    print("NOT RUN - DESIGN_ONLY mode performs no execution.")
elif SMOKE:
    OUT_DIR = "/content/q4p_smoke"
    cohort = Q4O.synthetic_cohort(n_record=8, n_beat=110, seed=17, n_unscorable=2)
    prov = {"abs_path": "<synthetic>", "file_name": "<synthetic>",
            "sha256": "<synthetic>", "synthetic": True}
    result = QP.run_diagnostic(cohort, prov, OUT_DIR, seeds=Q4O.TRAIN_SEEDS[:2],
                               epochs=2, batch=256, n_boot=100, device="cpu",
                               smoke=True)
    print("SMOKE ok - no scientific meaning. verdict field exercised:",
          result["decision_tree"]["verdict"])
elif FULL_RUN:
    assert os.path.exists(DATA_PATH), (
        f"{DATA_PATH} not found. Do NOT substitute svdb_data.npz - stop and "
        f"report a blocker.")
    cohort, prov = Q4O.load_cohort(DATA_PATH)
    TIMESTAMP = time.strftime("%Y%m%dT%H%M", time.gmtime())
    OUT_DIR = os.path.join(RUNS_DIR, QP.run_dir_name(TIMESTAMP))
    n_traj = 2 * len(QP.SCHEDULES) * len(Q4O.TRAIN_SEEDS) * Q4O.N_OUTER_FOLDS
    print("data sha256 :", prov["sha256"])
    print("git sha     :", Q4O.git_commit_sha(REPO_DIR))
    print("out dir     :", OUT_DIR)
    print("plan        :", n_traj, "trajectories x", QP.N_EPOCHS,
          "epochs (+ epoch -1 eval each)")
    print("expect      : roughly 6x Q4-O's Arm C wall time on a T4 "
          "(3 schedules x 2 arms, fixed 24 epochs, no early stop)")
    t0 = time.time()
    log = Q4O.RunLog()   # run_diagnostic logs [k/N] progress lines -> live ETA
    result = QP.run_diagnostic(cohort, prov, OUT_DIR, seeds=Q4O.TRAIN_SEEDS,
                               epochs=QP.N_EPOCHS, batch=Q4O.DL_BATCH,
                               n_boot=2000, smoke=False, log=log)
    print(f"wall time: {(time.time() - t0) / 60:.1f} min")
elif ANALYZE_EXISTING_RUN:
    OUT_DIR = (EXISTING_RUN_DIR if os.path.isabs(EXISTING_RUN_DIR)
               else os.path.join(RUNS_DIR, EXISTING_RUN_DIR))
    assert os.path.isdir(OUT_DIR), f"run bundle not found: {OUT_DIR}"
    QP.verify_bundle(OUT_DIR)          # incomplete bundle -> hard fail
    import json as _json
    result = _json.load(open(os.path.join(OUT_DIR, "result.json"),
                             encoding="utf-8"))
    hist = _json.load(open(os.path.join(OUT_DIR, "training_history.json"),
                           encoding="utf-8"))
    cohort, _prov = Q4O.load_cohort(DATA_PATH)
    fm = {int(k): int(v) for k, v in _json.load(open(os.path.join(
        OUT_DIR, "fold_map.json")))["record_to_fold"].items()}
    QP._write_figures_and_report(OUT_DIR, result, hist, cohort, sorted(fm),
                                 result.get("summary", {}).get("seeds",
                                 list(Q4O.TRAIN_SEEDS)), Q4O.RunLog())
    print("re-report complete - measured artifacts fingerprint-verified")
# Out:
# data sha256 : 892f6ae9635db9bf715272c323a3c0e62e71693608bf66ca4dc9b66b69915a85
# git sha     : a4e24f4d662b3a93727f6a3413e594b51cc6205e
# out dir     : /content/drive/MyDrive/MedKOS/ecg-model/runs/20260808T1310_EXP-2026-002_q4p_best_epoch_zero_diagnostic
# plan        : 150 trajectories x 24 epochs (+ epoch -1 eval each)
# expect      : roughly 6x Q4-O's Arm C wall time on a T4 (3 schedules x 2 arms, fixed 24 epochs, no early stop)
# [    0.7s] EXP-2026-002 / Q4-P diagnostic — device cuda, 5 seeds, 24 epochs/trajectory, smoke=False
# [   28.4s]     fold 0: offset cross-fitted over 44 train records (5 inner folds), 12 test records
# [   31.5s]     fold 1: offset cross-fitted over 45 train records (5 inner folds), 11 test records
# [   34.6s]     fold 2: offset cross-fitted over 45 train records (5 inner folds), 11 test records
# [   38.5s]     fold 3: offset cross-fitted over 45 train records (5 inner folds), 11 test records
# [   42.3s]     fold 4: offset cross-fitted over 45 train records (5 inner folds), 11 test records
# [   72.7s]   [1/150] morph_plus_raw_residual S0_original seed 20260806 fold 0: SEL0 ep 0 · SEL1 ep 0 · SEL2 ep -1
# [   97.7s]   [2/150] morph_plus_raw_residual S1_global_low seed 20260806 fold 0: SEL0 ep 2 · SEL1 ep 2 · SEL2 ep -1
# [  123.5s]   [3/150] morph_plus_raw_residual S2_alpha_low seed 20260806 fold 0: SEL0 ep 1 · SEL1 ep 1 · SEL2 ep -1
# [  149.5s]   [4/150] morph_plus_raw_residual S0_original seed 20260806 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [  175.5s]   [5/150] morph_plus_raw_residual S1_global_low seed 20260806 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 6
# [  201.5s]   [6/150] morph_plus_raw_residual S2_alpha_low seed 20260806 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 3
# [  227.8s]   [7/150] morph_plus_raw_residual S0_original seed 20260806 fold 2: SEL0 ep 4 · SEL1 ep 4 · SEL2 ep 14
# [  254.0s]   [8/150] morph_plus_raw_residual S1_global_low seed 20260806 fold 2: SEL0 ep 10 · SEL1 ep 10 · SEL2 ep 9
# [  280.2s]   [9/150] morph_plus_raw_residual S2_alpha_low seed 20260806 fold 2: SEL0 ep 14 · SEL1 ep 14 · SEL2 ep 5
# [  306.5s]   [10/150] morph_plus_raw_residual S0_original seed 20260806 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 4
# [  332.8s]   [11/150] morph_plus_raw_residual S1_global_low seed 20260806 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 6
# [  358.8s]   [12/150] morph_plus_raw_residual S2_alpha_low seed 20260806 fold 3: SEL0 ep 1 · SEL1 ep 1 · SEL2 ep 6
# [  384.6s]   [13/150] morph_plus_raw_residual S0_original seed 20260806 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [  410.4s]   [14/150] morph_plus_raw_residual S1_global_low seed 20260806 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 9
# [  436.2s]   [15/150] morph_plus_raw_residual S2_alpha_low seed 20260806 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 4
# [  462.0s]   [16/150] morph_plus_raw_residual S0_original seed 20260807 fold 0: SEL0 ep 0 · SEL1 ep 0 · SEL2 ep -1
# [  487.9s]   [17/150] morph_plus_raw_residual S1_global_low seed 20260807 fold 0: SEL0 ep 1 · SEL1 ep 1 · SEL2 ep -1
# [  513.8s]   [18/150] morph_plus_raw_residual S2_alpha_low seed 20260807 fold 0: SEL0 ep 2 · SEL1 ep 2 · SEL2 ep -1
# [  539.8s]   [19/150] morph_plus_raw_residual S0_original seed 20260807 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [  565.7s]   [20/150] morph_plus_raw_residual S1_global_low seed 20260807 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 6
# [  591.6s]   [21/150] morph_plus_raw_residual S2_alpha_low seed 20260807 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [  617.6s]   [22/150] morph_plus_raw_residual S0_original seed 20260807 fold 2: SEL0 ep 20 · SEL1 ep 20 · SEL2 ep 10
# [  643.7s]   [23/150] morph_plus_raw_residual S1_global_low seed 20260807 fold 2: SEL0 ep 11 · SEL1 ep 11 · SEL2 ep 17
# [  669.8s]   [24/150] morph_plus_raw_residual S2_alpha_low seed 20260807 fold 2: SEL0 ep 20 · SEL1 ep 19 · SEL2 ep 15
# [  695.9s]   [25/150] morph_plus_raw_residual S0_original seed 20260807 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 3
# [  722.1s]   [26/150] morph_plus_raw_residual S1_global_low seed 20260807 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 6
# [  748.2s]   [27/150] morph_plus_raw_residual S2_alpha_low seed 20260807 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 3
# [  774.1s]   [28/150] morph_plus_raw_residual S0_original seed 20260807 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [  799.9s]   [29/150] morph_plus_raw_residual S1_global_low seed 20260807 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 9
# [  825.6s]   [30/150] morph_plus_raw_residual S2_alpha_low seed 20260807 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 8
# [  851.4s]   [31/150] morph_plus_raw_residual S0_original seed 20260808 fold 0: SEL0 ep 0 · SEL1 ep 0 · SEL2 ep -1
# [  877.1s]   [32/150] morph_plus_raw_residual S1_global_low seed 20260808 fold 0: SEL0 ep 3 · SEL1 ep 3 · SEL2 ep -1
# [  902.9s]   [33/150] morph_plus_raw_residual S2_alpha_low seed 20260808 fold 0: SEL0 ep 2 · SEL1 ep 2 · SEL2 ep -1
# [  929.0s]   [34/150] morph_plus_raw_residual S0_original seed 20260808 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [  955.1s]   [35/150] morph_plus_raw_residual S1_global_low seed 20260808 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 5
# [  981.1s]   [36/150] morph_plus_raw_residual S2_alpha_low seed 20260808 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [ 1007.2s]   [37/150] morph_plus_raw_residual S0_original seed 20260808 fold 2: SEL0 ep 5 · SEL1 ep 5 · SEL2 ep 18
# [ 1033.2s]   [38/150] morph_plus_raw_residual S1_global_low seed 20260808 fold 2: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 6
# [ 1059.5s]   [39/150] morph_plus_raw_residual S2_alpha_low seed 20260808 fold 2: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 18
# [ 1085.7s]   [40/150] morph_plus_raw_residual S0_original seed 20260808 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 7
# [ 1111.7s]   [41/150] morph_plus_raw_residual S1_global_low seed 20260808 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 3
# [ 1137.8s]   [42/150] morph_plus_raw_residual S2_alpha_low seed 20260808 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 6
# [ 1163.8s]   [43/150] morph_plus_raw_residual S0_original seed 20260808 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 3
# [ 1189.6s]   [44/150] morph_plus_raw_residual S1_global_low seed 20260808 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 7
# [ 1215.3s]   [45/150] morph_plus_raw_residual S2_alpha_low seed 20260808 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 6
# [ 1241.1s]   [46/150] morph_plus_raw_residual S0_original seed 20260809 fold 0: SEL0 ep 10 · SEL1 ep 10 · SEL2 ep -1
# [ 1267.0s]   [47/150] morph_plus_raw_residual S1_global_low seed 20260809 fold 0: SEL0 ep 1 · SEL1 ep 0 · SEL2 ep -1
# [ 1292.7s]   [48/150] morph_plus_raw_residual S2_alpha_low seed 20260809 fold 0: SEL0 ep 10 · SEL1 ep 10 · SEL2 ep 1
# [ 1318.7s]   [49/150] morph_plus_raw_residual S0_original seed 20260809 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 0
# [ 1344.6s]   [50/150] morph_plus_raw_residual S1_global_low seed 20260809 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [ 1370.6s]   [51/150] morph_plus_raw_residual S2_alpha_low seed 20260809 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [ 1396.7s]   [52/150] morph_plus_raw_residual S0_original seed 20260809 fold 2: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 14
# [ 1422.9s]   [53/150] morph_plus_raw_residual S1_global_low seed 20260809 fold 2: SEL0 ep -1 · SEL1 ep 8 · SEL2 ep 8
# [ 1449.0s]   [54/150] morph_plus_raw_residual S2_alpha_low seed 20260809 fold 2: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 13
# [ 1475.1s]   [55/150] morph_plus_raw_residual S0_original seed 20260809 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 7
# [ 1501.2s]   [56/150] morph_plus_raw_residual S1_global_low seed 20260809 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 5
# [ 1527.3s]   [57/150] morph_plus_raw_residual S2_alpha_low seed 20260809 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 3
# [ 1553.1s]   [58/150] morph_plus_raw_residual S0_original seed 20260809 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 6
# [ 1578.8s]   [59/150] morph_plus_raw_residual S1_global_low seed 20260809 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 8
# [ 1604.5s]   [60/150] morph_plus_raw_residual S2_alpha_low seed 20260809 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 6
# [ 1630.3s]   [61/150] morph_plus_raw_residual S0_original seed 20260810 fold 0: SEL0 ep 0 · SEL1 ep 0 · SEL2 ep -1
# [ 1656.4s]   [62/150] morph_plus_raw_residual S1_global_low seed 20260810 fold 0: SEL0 ep 3 · SEL1 ep 3 · SEL2 ep 0
# [ 1682.3s]   [63/150] morph_plus_raw_residual S2_alpha_low seed 20260810 fold 0: SEL0 ep 1 · SEL1 ep 1 · SEL2 ep -1
# [ 1708.3s]   [64/150] morph_plus_raw_residual S0_original seed 20260810 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [ 1734.3s]   [65/150] morph_plus_raw_residual S1_global_low seed 20260810 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [ 1760.5s]   [66/150] morph_plus_raw_residual S2_alpha_low seed 20260810 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [ 1786.6s]   [67/150] morph_plus_raw_residual S0_original seed 20260810 fold 2: SEL0 ep 22 · SEL1 ep 22 · SEL2 ep 1
# [ 1812.8s]   [68/150] morph_plus_raw_residual S1_global_low seed 20260810 fold 2: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 4
# [ 1838.8s]   [69/150] morph_plus_raw_residual S2_alpha_low seed 20260810 fold 2: SEL0 ep 13 · SEL1 ep 13 · SEL2 ep 15
# [ 1865.0s]   [70/150] morph_plus_raw_residual S0_original seed 20260810 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 9
# [ 1891.4s]   [71/150] morph_plus_raw_residual S1_global_low seed 20260810 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 6
# [ 1917.6s]   [72/150] morph_plus_raw_residual S2_alpha_low seed 20260810 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 12
# [ 1943.8s]   [73/150] morph_plus_raw_residual S0_original seed 20260810 fold 4: SEL0 ep -1 · SEL1 ep 0 · SEL2 ep 1
# [ 1969.6s]   [74/150] morph_plus_raw_residual S1_global_low seed 20260810 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 7
# [ 1995.5s]   [75/150] morph_plus_raw_residual S2_alpha_low seed 20260810 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 9
# [ 2021.3s]   [76/150] shuffled_waveform_control S0_original seed 20260806 fold 0: SEL0 ep 0 · SEL1 ep 0 · SEL2 ep -1
# [ 2047.3s]   [77/150] shuffled_waveform_control S1_global_low seed 20260806 fold 0: SEL0 ep 1 · SEL1 ep 1 · SEL2 ep -1
# [ 2073.2s]   [78/150] shuffled_waveform_control S2_alpha_low seed 20260806 fold 0: SEL0 ep 23 · SEL1 ep 23 · SEL2 ep -1
# [ 2099.2s]   [79/150] shuffled_waveform_control S0_original seed 20260806 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 2125.3s]   [80/150] shuffled_waveform_control S1_global_low seed 20260806 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [ 2151.4s]   [81/150] shuffled_waveform_control S2_alpha_low seed 20260806 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 0
# [ 2177.7s]   [82/150] shuffled_waveform_control S0_original seed 20260806 fold 2: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 19
# [ 2204.0s]   [83/150] shuffled_waveform_control S1_global_low seed 20260806 fold 2: SEL0 ep 19 · SEL1 ep 19 · SEL2 ep 3
# [ 2230.2s]   [84/150] shuffled_waveform_control S2_alpha_low seed 20260806 fold 2: SEL0 ep 8 · SEL1 ep 8 · SEL2 ep 2
# [ 2256.3s]   [85/150] shuffled_waveform_control S0_original seed 20260806 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 0
# [ 2282.6s]   [86/150] shuffled_waveform_control S1_global_low seed 20260806 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [ 2308.8s]   [87/150] shuffled_waveform_control S2_alpha_low seed 20260806 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [ 2334.7s]   [88/150] shuffled_waveform_control S0_original seed 20260806 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 2360.7s]   [89/150] shuffled_waveform_control S1_global_low seed 20260806 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 0
# [ 2386.7s]   [90/150] shuffled_waveform_control S2_alpha_low seed 20260806 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 21
# [ 2412.6s]   [91/150] shuffled_waveform_control S0_original seed 20260807 fold 0: SEL0 ep 0 · SEL1 ep 0 · SEL2 ep 0
# [ 2438.7s]   [92/150] shuffled_waveform_control S1_global_low seed 20260807 fold 0: SEL0 ep 1 · SEL1 ep 1 · SEL2 ep -1
# [ 2464.7s]   [93/150] shuffled_waveform_control S2_alpha_low seed 20260807 fold 0: SEL0 ep 0 · SEL1 ep 0 · SEL2 ep -1
# [ 2490.8s]   [94/150] shuffled_waveform_control S0_original seed 20260807 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 2517.0s]   [95/150] shuffled_waveform_control S1_global_low seed 20260807 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [ 2543.1s]   [96/150] shuffled_waveform_control S2_alpha_low seed 20260807 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 2569.3s]   [97/150] shuffled_waveform_control S0_original seed 20260807 fold 2: SEL0 ep 12 · SEL1 ep 12 · SEL2 ep 11
# [ 2595.6s]   [98/150] shuffled_waveform_control S1_global_low seed 20260807 fold 2: SEL0 ep 19 · SEL1 ep 19 · SEL2 ep 3
# [ 2621.9s]   [99/150] shuffled_waveform_control S2_alpha_low seed 20260807 fold 2: SEL0 ep 15 · SEL1 ep 15 · SEL2 ep 2
# [ 2648.0s]   [100/150] shuffled_waveform_control S0_original seed 20260807 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 2674.4s]   [101/150] shuffled_waveform_control S1_global_low seed 20260807 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [ 2701.0s]   [102/150] shuffled_waveform_control S2_alpha_low seed 20260807 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [ 2727.3s]   [103/150] shuffled_waveform_control S0_original seed 20260807 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 2753.6s]   [104/150] shuffled_waveform_control S1_global_low seed 20260807 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 0
# [ 2779.7s]   [105/150] shuffled_waveform_control S2_alpha_low seed 20260807 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 15
# [ 2805.9s]   [106/150] shuffled_waveform_control S0_original seed 20260808 fold 0: SEL0 ep 0 · SEL1 ep 0 · SEL2 ep -1
# [ 2832.1s]   [107/150] shuffled_waveform_control S1_global_low seed 20260808 fold 0: SEL0 ep 1 · SEL1 ep 1 · SEL2 ep -1
# [ 2858.4s]   [108/150] shuffled_waveform_control S2_alpha_low seed 20260808 fold 0: SEL0 ep 0 · SEL1 ep 0 · SEL2 ep -1
# [ 2884.7s]   [109/150] shuffled_waveform_control S0_original seed 20260808 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 2910.9s]   [110/150] shuffled_waveform_control S1_global_low seed 20260808 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 0
# [ 2937.1s]   [111/150] shuffled_waveform_control S2_alpha_low seed 20260808 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 0
# [ 2963.6s]   [112/150] shuffled_waveform_control S0_original seed 20260808 fold 2: SEL0 ep 10 · SEL1 ep 10 · SEL2 ep 4
# [ 2990.3s]   [113/150] shuffled_waveform_control S1_global_low seed 20260808 fold 2: SEL0 ep 16 · SEL1 ep 16 · SEL2 ep 3
# [ 3016.7s]   [114/150] shuffled_waveform_control S2_alpha_low seed 20260808 fold 2: SEL0 ep 16 · SEL1 ep 16 · SEL2 ep 2
# [ 3043.2s]   [115/150] shuffled_waveform_control S0_original seed 20260808 fold 3: SEL0 ep -1 · SEL1 ep 0 · SEL2 ep 1
# [ 3069.6s]   [116/150] shuffled_waveform_control S1_global_low seed 20260808 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 3
# [ 3096.1s]   [117/150] shuffled_waveform_control S2_alpha_low seed 20260808 fold 3: SEL0 ep -1 · SEL1 ep 1 · SEL2 ep 3
# [ 3122.1s]   [118/150] shuffled_waveform_control S0_original seed 20260808 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 3148.0s]   [119/150] shuffled_waveform_control S1_global_low seed 20260808 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [ 3174.0s]   [120/150] shuffled_waveform_control S2_alpha_low seed 20260808 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 9
# [ 3200.0s]   [121/150] shuffled_waveform_control S0_original seed 20260809 fold 0: SEL0 ep 0 · SEL1 ep 0 · SEL2 ep -1
# [ 3226.0s]   [122/150] shuffled_waveform_control S1_global_low seed 20260809 fold 0: SEL0 ep 1 · SEL1 ep 1 · SEL2 ep -1
# [ 3252.1s]   [123/150] shuffled_waveform_control S2_alpha_low seed 20260809 fold 0: SEL0 ep 1 · SEL1 ep 1 · SEL2 ep -1
# [ 3278.4s]   [124/150] shuffled_waveform_control S0_original seed 20260809 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 3304.6s]   [125/150] shuffled_waveform_control S1_global_low seed 20260809 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [ 3330.8s]   [126/150] shuffled_waveform_control S2_alpha_low seed 20260809 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 3357.2s]   [127/150] shuffled_waveform_control S0_original seed 20260809 fold 2: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 23
# [ 3383.6s]   [128/150] shuffled_waveform_control S1_global_low seed 20260809 fold 2: SEL0 ep 22 · SEL1 ep 22 · SEL2 ep 2
# [ 3410.1s]   [129/150] shuffled_waveform_control S2_alpha_low seed 20260809 fold 2: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 10
# [ 3436.5s]   [130/150] shuffled_waveform_control S0_original seed 20260809 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 3463.0s]   [131/150] shuffled_waveform_control S1_global_low seed 20260809 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 3
# [ 3489.3s]   [132/150] shuffled_waveform_control S2_alpha_low seed 20260809 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [ 3515.4s]   [133/150] shuffled_waveform_control S0_original seed 20260809 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 3541.6s]   [134/150] shuffled_waveform_control S1_global_low seed 20260809 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 0
# [ 3568.2s]   [135/150] shuffled_waveform_control S2_alpha_low seed 20260809 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 3594.5s]   [136/150] shuffled_waveform_control S0_original seed 20260810 fold 0: SEL0 ep 0 · SEL1 ep -1 · SEL2 ep -1
# [ 3620.7s]   [137/150] shuffled_waveform_control S1_global_low seed 20260810 fold 0: SEL0 ep 1 · SEL1 ep 1 · SEL2 ep -1
# [ 3646.9s]   [138/150] shuffled_waveform_control S2_alpha_low seed 20260810 fold 0: SEL0 ep 1 · SEL1 ep 0 · SEL2 ep -1
# [ 3673.1s]   [139/150] shuffled_waveform_control S0_original seed 20260810 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 3699.2s]   [140/150] shuffled_waveform_control S1_global_low seed 20260810 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [ 3725.4s]   [141/150] shuffled_waveform_control S2_alpha_low seed 20260810 fold 1: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 0
# [ 3751.7s]   [142/150] shuffled_waveform_control S0_original seed 20260810 fold 2: SEL0 ep 8 · SEL1 ep -1 · SEL2 ep 15
# [ 3778.1s]   [143/150] shuffled_waveform_control S1_global_low seed 20260810 fold 2: SEL0 ep 15 · SEL1 ep 15 · SEL2 ep 2
# [ 3804.3s]   [144/150] shuffled_waveform_control S2_alpha_low seed 20260810 fold 2: SEL0 ep 8 · SEL1 ep 8 · SEL2 ep 1
# [ 3830.6s]   [145/150] shuffled_waveform_control S0_original seed 20260810 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [ 3857.1s]   [146/150] shuffled_waveform_control S1_global_low seed 20260810 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 2
# [ 3883.5s]   [147/150] shuffled_waveform_control S2_alpha_low seed 20260810 fold 3: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep -1
# [ 3909.6s]   [148/150] shuffled_waveform_control S0_original seed 20260810 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 20
# [ 3935.7s]   [149/150] shuffled_waveform_control S1_global_low seed 20260810 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 1
# [ 3961.7s]   [150/150] shuffled_waveform_control S2_alpha_low seed 20260810 fold 4: SEL0 ep -1 · SEL1 ep -1 · SEL2 ep 20
# [ 3961.7s] all trajectories complete — assembling selected-checkpoint test scores
# [ 3964.5s] decision tree verdict: B3_lr_or_alpha_overshoot
# [ 3987.0s] figures + report written; measured artifacts unchanged (26 fingerprints)
# [ 3987.1s] bundle complete: /content/drive/MyDrive/MedKOS/ecg-model/runs/20260808T1310_EXP-2026-002_q4p_best_epoch_zero_diagnostic
# wall time: 66.5 min

# %% [markdown]
# ## 6. 원인 판정 (decision tree)

# %%
if result is None:
    print("NOT RUN - no measured decision tree exists yet.")
else:
    dec = result["decision_tree"]
    for b in QP.DECISION_BRANCHES:
        info = dec["branches"].get(b, {})
        state = ("NOT EVALUABLE" if not info.get("evaluable")
                 else ("FIRES" if info.get("fires") else "-"))
        print(f"{state:>14}  {b}")
    print()
    print("verdict:", dec["verdict"])
    if result.get("smoke"):
        print("(SYNTHETIC smoke - the verdict above has no scientific meaning)")
# Out:
#              -  B1_immediately_harmful_or_no_signal
#              -  B2_first_epoch_then_overfit
#          FIRES  B3_lr_or_alpha_overshoot
#              -  B4_selector_mismatch
#              -  B5_schedule_artifact_not_waveform_specific
#              -  B6_real_waveform_residual_candidate
#
# verdict: B3_lr_or_alpha_overshoot

# %% [markdown]
# ## 7. 핵심 표 — best epoch 분포와 C−D

# %%
if result is None:
    print("NOT RUN")
else:
    s = result["summary"]
    print("P(best = -1 / 0 / >0), primary selector", result["primary_selector"])
    for arm in (Q4O.ARM_C, Q4O.ARM_D):
        for sch in QP.SCHEDULE_NAMES:
            d = s["best_epoch_dist"][arm][sch][result["primary_selector"]]
            print(f"  {arm:28s} {sch:14s} "
                  f"P(-1)={d['p_pretrain']:.2f} P(0)={d['p_epoch0']:.2f} "
                  f"P(>0)={d['p_later']:.2f}")
    print()
    print("C - D (record k-sweep, paired bootstrap), all schedules x selectors:")
    for sch in QP.SCHEDULE_NAMES:
        for sel in QP.SELECTORS:
            c = s["contrasts"][sch][sel]["C_minus_D"]["record_bootstrap"]
            tag = " <- primary" if sel == result["primary_selector"] else ""
            print(f"  {sch:14s} {sel:18s} {c['mean']:+.4f} "
                  f"[{c['ci_low']:+.4f}, {c['ci_high']:+.4f}]{tag}")
# Out:
# P(best = -1 / 0 / >0), primary selector SEL1_record_bce
#   morph_plus_raw_residual      S0_original    P(-1)=0.60 P(0)=0.20 P(>0)=0.20
#   morph_plus_raw_residual      S1_global_low  P(-1)=0.68 P(0)=0.04 P(>0)=0.28
#   morph_plus_raw_residual      S2_alpha_low   P(-1)=0.64 P(0)=0.00 P(>0)=0.36
#   shuffled_waveform_control    S0_original    P(-1)=0.72 P(0)=0.20 P(>0)=0.08
#   shuffled_waveform_control    S1_global_low  P(-1)=0.60 P(0)=0.00 P(>0)=0.40
#   shuffled_waveform_control    S2_alpha_low   P(-1)=0.60 P(0)=0.12 P(>0)=0.28
#
# C - D (record k-sweep, paired bootstrap), all schedules x selectors:
#   S0_original    SEL0_pooled_bce    +0.0020 [-0.0053, +0.0097]
#   S0_original    SEL1_record_bce    +0.0014 [-0.0061, +0.0093] <- primary
#   S0_original    SEL2_record_ksweep -0.0020 [-0.0116, +0.0072]
#   S1_global_low  SEL0_pooled_bce    +0.0038 [-0.0007, +0.0087]
#   S1_global_low  SEL1_record_bce    +0.0046 [-0.0004, +0.0099] <- primary
#   S1_global_low  SEL2_record_ksweep -0.0022 [-0.0101, +0.0052]
#   S2_alpha_low   SEL0_pooled_bce    +0.0046 [-0.0022, +0.0122]
#   S2_alpha_low   SEL1_record_bce    +0.0048 [-0.0019, +0.0124] <- primary
#   S2_alpha_low   SEL2_record_ksweep -0.0003 [-0.0083, +0.0075]

# %% [markdown]
# ## 8. 그림

# %%
if result is None or OUT_DIR is None:
    print("NOT RUN")
else:
    from IPython.display import display, Markdown, Image
    for name in QP.FIGURE_FILES:
        p = os.path.join(OUT_DIR, "figures", name)
        if os.path.exists(p):
            display(Markdown(f"### `{name}`"))
            display(Image(filename=p))
        else:
            print("missing figure:", name)
# Out:
# ### `learning_curves_by_schedule.png`
# ### `pretrain_vs_epoch0.png`
# ### `best_epoch_distribution.png`
# ### `alpha_and_effective_residual.png`
# ### `gradient_update_diagnostics.png`
# ### `selector_disagreement.png`
# ### `c_vs_d_by_schedule.png`
# ### `patient_delta_waterfall.png`
# ### `decision_matrix.png`

# %% [markdown]
# ## 9. report_summary.md

# %%
if result is None or OUT_DIR is None:
    print("NOT RUN")
else:
    from IPython.display import display, Markdown
    display(Markdown(open(os.path.join(OUT_DIR, "figures", "report_summary.md"),
                          encoding="utf-8").read()))
# Out:
# # EXP-2026-002 / Q4-P — best_epoch=0 원인 분리 진단
#
# - 상태: **MEASURED**
# - 주 selector: `SEL1_record_bce`
# - 판정: **B3_lr_or_alpha_overshoot**
#
# ## best epoch 분포 (P(-1) / P(0) / P(>0))
#
# - morph_plus_raw_residual · S0_original: P(-1)=0.60 P(0)=0.20 P(>0)=0.20
# - morph_plus_raw_residual · S1_global_low: P(-1)=0.68 P(0)=0.04 P(>0)=0.28
# - morph_plus_raw_residual · S2_alpha_low: P(-1)=0.64 P(0)=0.00 P(>0)=0.36
# - shuffled_waveform_control · S0_original: P(-1)=0.72 P(0)=0.20 P(>0)=0.08
# - shuffled_waveform_control · S1_global_low: P(-1)=0.60 P(0)=0.00 P(>0)=0.40
# - shuffled_waveform_control · S2_alpha_low: P(-1)=0.60 P(0)=0.12 P(>0)=0.28
#
# ## C-D (주 selector, schedule별)
#
# - S0_original: +0.0014 [-0.0061, +0.0093]
# - S1_global_low: +0.0046 [-0.0004, +0.0099]
# - S2_alpha_low: +0.0048 [-0.0019, +0.0124]
#
# ## 사전등록 decision tree
#
# - `B1_immediately_harmful_or_no_signal`: 미발화
# - `B2_first_epoch_then_overfit`: 미발화
# - `B3_lr_or_alpha_overshoot`: 발화
# - `B4_selector_mismatch`: 미발화
# - `B5_schedule_artifact_not_waveform_specific`: 미발화
# - `B6_real_waveform_residual_candidate`: 미발화
#
# **최종 판정: B3_lr_or_alpha_overshoot**
#
# epoch -1(학습 전)과 epoch 0(첫 학습 epoch 완료)은 모든 표·그림에서 빨강/주황으로 구분 표기된다. test trajectory 전체는 exploratory이며 schedule 선택이나 baseline 승격에 사용되지 않았다.

# %% [markdown]
# ## 10. 번들 검증

# %%
if result is None or OUT_DIR is None:
    print("NOT RUN - nothing was executed in this session.")
    print("This notebook is the pre-registered runner for EXP-2026-002.")
    print("FULL RESULT NOT RUN.")
else:
    for root, dirs, files in os.walk(OUT_DIR):
        for f_ in sorted(files):
            p = os.path.join(root, f_)
            print(f"  {os.path.relpath(p, OUT_DIR):<58} "
                  f"{os.path.getsize(p):>10,d} bytes")
    QP.verify_bundle(OUT_DIR)
    print()
    print("bundle schema verified")
# Out:
#   checkpoint_table.csv                                           31,391 bytes
#   config.json                                                     1,414 bytes
#   fold_map.json                                                     637 bytes
#   log.txt                                                        18,770 bytes
#   manifest.json                                                   3,951 bytes
#   predictions.npz                                            53,301,433 bytes
#   result.json                                                    31,593 bytes
#   training_history.json                                       6,306,652 bytes
#   trajectory_table.csv                                        1,142,855 bytes
#   arms/morph_plus_raw_residual/S0_original/SEL0_pooled_bce/probs.npy  7,376,008 bytes
#   arms/morph_plus_raw_residual/S0_original/SEL1_record_bce/probs.npy  7,376,008 bytes
#   arms/morph_plus_raw_residual/S0_original/SEL2_record_ksweep/probs.npy  7,376,008 bytes
#   arms/morph_plus_raw_residual/S1_global_low/SEL0_pooled_bce/probs.npy  7,376,008 bytes
#   arms/morph_plus_raw_residual/S1_global_low/SEL1_record_bce/probs.npy  7,376,008 bytes
#   arms/morph_plus_raw_residual/S1_global_low/SEL2_record_ksweep/probs.npy  7,376,008 bytes
#   arms/morph_plus_raw_residual/S2_alpha_low/SEL0_pooled_bce/probs.npy  7,376,008 bytes
#   arms/morph_plus_raw_residual/S2_alpha_low/SEL1_record_bce/probs.npy  7,376,008 bytes
#   arms/morph_plus_raw_residual/S2_alpha_low/SEL2_record_ksweep/probs.npy  7,376,008 bytes
#   arms/shuffled_waveform_control/S0_original/SEL0_pooled_bce/probs.npy  7,376,008 bytes
#   arms/shuffled_waveform_control/S0_original/SEL1_record_bce/probs.npy  7,376,008 bytes
#   arms/shuffled_waveform_control/S0_original/SEL2_record_ksweep/probs.npy  7,376,008 bytes
#   arms/shuffled_waveform_control/S1_global_low/SEL0_pooled_bce/probs.npy  7,376,008 bytes
#   arms/shuffled_waveform_control/S1_global_low/SEL1_record_bce/probs.npy  7,376,008 bytes
#   arms/shuffled_waveform_control/S1_global_low/SEL2_record_ksweep/probs.npy  7,376,008 bytes
#   arms/shuffled_waveform_control/S2_alpha_low/SEL0_pooled_bce/probs.npy  7,376,008 bytes
#   arms/shuffled_waveform_control/S2_alpha_low/SEL1_record_bce/probs.npy  7,376,008 bytes
#   arms/shuffled_waveform_control/S2_alpha_low/SEL2_record_ksweep/probs.npy  7,376,008 bytes
#   figures/alpha_and_effective_residual.png                      698,349 bytes
#   figures/best_epoch_distribution.png                            53,368 bytes
#   figures/c_vs_d_by_schedule.png                                 31,769 bytes
#   figures/decision_matrix.png                                    42,649 bytes
#   figures/gradient_update_diagnostics.png                       774,260 bytes
#   figures/learning_curves_by_schedule.png                     1,343,535 bytes
#   figures/patient_delta_waterfall.png                            31,407 bytes
#   figures/pretrain_vs_epoch0.png                                 81,092 bytes
#   figures/report_summary.md                                       1,414 bytes
#   figures/selector_disagreement.png                              40,742 bytes
#
# bundle schema verified
